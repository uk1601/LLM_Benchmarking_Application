# %%
from sqlalchemy import create_engine, MetaData, Table, select, func, case
from sqlalchemy.orm import sessionmaker
import random
from datetime import datetime

# Database connection parameters
params = {
    'host': "******",
    'port': "******",
    'database': "******",
    'user': "******",
    'password': "******"
}

# Construct the database URL for SQLAlchemy
DATABASE_URL = f"postgresql+psycopg2://{params['user']}:{params['password']}@{params['host']}:{params['port']}/{params['database']}"

# Create the SQLAlchemy engine
engine = create_engine(DATABASE_URL)
metadata = MetaData()

# %%
# Function to list all tables in the database
def list_tables():
    metadata.reflect(bind=engine)
    tables = metadata.tables.keys()
    print("Tables in the database:")
    for table in tables:
        print(table)

# Function to list columns and optionally fetch data from a table
def list_columns_and_data(table_name, fetch_data=False):
    metadata.reflect(bind=engine)
    if table_name not in metadata.tables:
        print(f"Table {table_name} does not exist.")
        return
    
    table = metadata.tables[table_name]
    columns = [column.name for column in table.columns]
    print(f"Columns in table {table_name}: {columns}")
    
    if fetch_data:
        with engine.connect() as connection:
            select_query = select(table)
            result = connection.execute(select_query)
            for row in result.fetchall():
                print(row)


# Insert random data into 'llms' and 'llmresponses' tables
def insert_random_data(start,end):

    # Begin a transaction
    with engine.begin() as connection:
        # Reflect the metadata of the database tables
        metadata.reflect(bind=engine)

        # Insert into llms table
        llms_table = metadata.tables['llms']
        llms_data = [
            {'llmid': 1, 'llmname': 'GPT-3', 'version': 'v1', 'parameters': 175000000000},
            {'llmid': 2, 'llmname': 'GPT-4', 'version': 'v2', 'parameters': 175000000000},
            {'llmid': 3, 'llmname': 'ChatGPT', 'version': 'v1', 'parameters': 6800000000}
        ]
        connection.execute(llms_table.insert().values(llms_data))
        print("Inserted data into llms table.")

        # Fetch task data from 'tasks' table
        tasks_table = metadata.tables['tasks']
        tasks = connection.execute(select(tasks_table.c.taskid, tasks_table.c.expectedanswer)).fetchall()

        # Insert into llmresponses table
        llmresponses_table = metadata.tables['llmresponses']
        is_annotated_options = [True, False]
        result_category_options = ['AS IS', 'With Annotation', 'Helpless!']

        for i in range(start,end):
            task = random.choice(tasks)
            taskid = task.taskid
            responsetext = task.expectedanswer
            llmid = random.choice([1, 2, 3])  # Random LLM ID
            isannotated = random.choice(is_annotated_options)
            resultcategory = random.choice(result_category_options)
            timestamp = datetime.now()

            connection.execute(llmresponses_table.insert().values(
                responseid=i,
                taskid=taskid,
                llmid=llmid,
                responsetext=responsetext,
                isannotated=isannotated,
                resultcategory=resultcategory,
                timestamp=timestamp
            ))

        print("Inserted data into llmresponses table.")

# %%
# Execute the functions
list_tables()
# Out:
# Tables in the database:
# tasks
# llmresponses
# llms

# %%
list_columns_and_data('tasks', fetch_data=False)
list_columns_and_data('llms',True)
list_columns_and_data('llmresponses',True)
# Out:
# Columns in table tasks: ['taskid', 'question', 'expectedanswer', 'level', 'filename', 'filepath', 'annotations']
# Columns in table llms: ['llmid', 'llmname', 'version', 'parameters']
# Columns in table llmresponses: ['responseid', 'taskid', 'llmid', 'responsetext', 'isannotated', 'resultcategory', 'timestamp']

# %%
# Function to delete all data from the llms and llmresponses tables
def delete_data():
    # Start a session
    Session = sessionmaker(bind=engine)
    session = Session()

    # Reflect the tables
    metadata.reflect(bind=engine)
    llms_table = metadata.tables['llms']
    llmresponses_table = metadata.tables['llmresponses']

    try:
        # Delete data from the 'llmresponses' table
        session.execute(llmresponses_table.delete())
        print("Deleted all data from llmresponses table.")

        # Delete data from the 'llms' table
        session.execute(llms_table.delete())
        print("Deleted all data from llms table.")

        # Commit the transaction
        session.commit()

    except Exception as e:
        # Rollback in case of any errors
        session.rollback()
        print(f"An error occurred: {e}")
    
    finally:
        # Close the session
        session.close()

# Execute the delete function
delete_data()
# Out:
# Deleted all data from llmresponses table.
# Deleted all data from llms table.

# %%
# Execute the insert function
insert_random_data(1,1001)
# Out:
# Inserted data into llms table.
# Inserted data into llmresponses table.

# %%
list_columns_and_data('llms',True)
# Out:
# Columns in table llms: ['llmid', 'llmname', 'version', 'parameters']
# (1, 'GPT-3', 'v1', '175000000000')
# (2, 'GPT-4', 'v2', '175000000000')
# (3, 'ChatGPT', 'v1', '6800000000')

# %%
list_columns_and_data('llmresponses',True)
# Out:
# Columns in table llmresponses: ['responseid', 'taskid', 'llmid', 'responsetext', 'isannotated', 'resultcategory', 'timestamp']
# (1, 'cca70ce6-1952-45d2-acd4-80c903b0bc49', 2, '85', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 57, 791818))
# (2, 'd700d50d-c707-4dca-90dc-4528cddd0c80', 3, 'Roger Miller', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 57, 836130))
# (3, 'f2feb6a4-363c-4c09-a804-0db564eafd68', 1, '900000', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 57, 879181))
# (4, '8b3379c0-0981-4f5b-8407-6444610cb212', 1, '1.8', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 57, 922068))
# (5, '2d83110e-a098-4ebb-9987-066c06fa42d0', 1, 'Right', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 57, 968434))
# (6, '6359a0b1-8f7b-499b-9336-840f9ab90688', 2, '39', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 58, 12673))
# (7, '65afbc8a-89ca-4ad5-8d62-355bb401f61d', 3, 'F478A7', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 58, 53735))
# (8, 'cca70ce6-1952-45d2-acd4-80c903b0bc49', 2, '85', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 58, 97726))
# (9, 'cca530fc-4052-43b2-b130-b30968d8aa44', 2, 'Rd5', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 58, 142563))
# (10, 'a26649c6-1cb2-470a-871e-6910c64c3e53', 3, '116', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 58, 189114))
# (11, '99c9cc74-fdc8-46c6-8f8d-3ce2d3bfeea3', 3, 'cornstarch, freshly squeezed lemon juice, granulated sugar, pure vanilla extract, ripe strawberries', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 58, 233235))
# (12, 'c365c1c7-a3db-4d5e-a9a1-66f56eae7865', 1, 'Braintree, Honolulu', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 58, 277708))
# (13, 'da52d699-e8d2-4dc5-9191-a2199e0b6a9b', 3, 'Out of the Silent Planet', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 58, 318533))
# (14, 'd8152ad6-e4d5-4c12-8bb7-8d57dc10c6de', 3, '0.03', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 58, 368482))
# (15, 'e2d69698-bc99-4e85-9880-67eaccd66e6c', 3, 'Michele Fitzgerald', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 58, 423159))
# (16, '8131e2c0-0083-4265-9ce7-78c2d568425d', 2, '101.376, 84.348', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 58, 470785))
# (17, '71345b0a-9c7d-4b50-b2bf-937ec5879845', 2, 'Here be dragons', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 58, 517151))
# (18, '853c8244-429e-46ca-89f2-addf40dfb2bd', 1, '11', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 58, 562430))
# (19, '0bb3b44a-ede5-4db5-a520-4e844b0079c5', 2, '536', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 58, 609446))
# (20, '7bd855d8-463d-4ed5-93ca-5fe35145f733', 3, '89706.00', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 58, 655402))
# (21, '46719c30-f4c3-4cad-be07-d5cb21eee6bb', 2, 'Mapping Human Oriented Information to Software Agents for Online Systems Usage', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 58, 705378))
# (22, '4d0aa727-86b1-406b-9b33-f870dd14a4a5', 1, '1 in 3', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 58, 753268))
# (23, '5cfb274c-0207-4aa7-9575-6ac0bd95d9b2', 3, 'No', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 58, 803398))
# (24, '8e867cd7-cff9-4e6c-867a-ff5ddc2550be', 3, '3', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 58, 855254))
# (25, '7673d772-ef80-4f0f-a602-1bf4485c9b43', 2, 'inference', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 58, 900443))
# (26, '676e5e31-a554-4acc-9286-b60d90a92d26', 2, '86', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 58, 949216))
# (27, '983bba7c-c092-455f-b6c9-7857003d48fc', 3, 'mice', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 58, 988822))
# (28, '54612da3-fd56-4941-80f4-5eb82330de25', 1, '60', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 59, 40139))
# (29, '72e110e7-464c-453c-a309-90a95aed6538', 1, 'Guatemala', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 59, 84828))
# (30, 'e0c10771-d627-4fd7-9694-05348e54ee36', 2, '234.9', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 59, 126581))
# (31, '5f982798-16b9-4051-ab57-cfc7ebdb2a91', 2, '0.2', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 59, 179783))
# (32, '4d0aa727-86b1-406b-9b33-f870dd14a4a5', 1, '1 in 3', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 59, 226673))
# (33, '5cfb274c-0207-4aa7-9575-6ac0bd95d9b2', 1, 'No', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 59, 271542))
# (34, 'edd4d4f2-1a58-45c4-b038-67337af4e029', 3, 'Berkshire', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 59, 316519))
# (35, 'e961a717-6b25-4175-8a68-874d28190ee4', 3, '12', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 59, 362385))
# (36, '42d4198c-5895-4f0a-b0c0-424a66465d83', 2, '60', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 59, 406043))
# (37, 'bfcd99e1-0690-4b53-a85c-0174a8629083', 3, '17', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 59, 451050))
# (38, '27d5d136-8563-469e-92bf-fd103c28b57c', 3, '(¬A → B) ↔ (A ∨ ¬B)', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 59, 495994))
# (39, 'f2feb6a4-363c-4c09-a804-0db564eafd68', 3, '900000', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 59, 540813))
# (40, '4fc2f1ae-8625-45b5-ab34-ad4433bc21f8', 2, 'FunkMonk', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 59, 585904))
# (41, 'e2d69698-bc99-4e85-9880-67eaccd66e6c', 1, 'Michele Fitzgerald', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 59, 630642))
# (42, '0ff53813-3367-4f43-bcbd-3fd725c1bf4b', 2, 'beta geometric', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 59, 677476))
# (43, '0e9e85b8-52b9-4de4-b402-5f635ab9631f', 2, '1927', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 59, 721237))
# (44, '676e5e31-a554-4acc-9286-b60d90a92d26', 2, '86', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 59, 770964))
# (45, '11af4e1a-5f45-467d-9aeb-46f4bb0bf034', 1, '6', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 25, 59, 815494))
# (46, '935e2cff-ae78-4218-b3f5-115589b19dae', 2, 'research', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 25, 59, 874147))
# (47, '935e2cff-ae78-4218-b3f5-115589b19dae', 3, 'research', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 59, 922028))
# (48, 'dd3c7503-f62a-4bd0-9f67-1b63b94194cc', 1, '6', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 25, 59, 967370))
# (49, '624cbf11-6a41-4692-af9c-36b3e5ca3130', 1, 'So we had to let it die.', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 0, 22380))
# (50, '8131e2c0-0083-4265-9ce7-78c2d568425d', 2, '101.376, 84.348', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 0, 67295))
# (51, 'f46b4380-207e-4434-820b-f32ce04ae2a4', 2, 'Harbinger, Tidal', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 0, 112311))
# (52, 'ded28325-3447-4c56-860f-e497d6fb3577', 3, 'Picnic is in Ploybius Plaza.', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 0, 165781))
# (53, '20194330-9976-4043-8632-f8485c6c71b2', 3, '4', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 0, 213493))
# (54, 'c61d22de-5f6c-4958-a7f6-5e9707bd3466', 2, 'egalitarian', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 0, 259574))
# (55, '1dcc160f-c187-48c2-b68e-319bd4354f3d', 2, '3', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 0, 304924))
# (56, 'e8cb5b03-41e0-4086-99e5-f6806cd97211', 3, 'shrimp', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 0, 348962))
# (57, '08f3a05f-5947-4089-a4c4-d4bcfaa6b7a0', 3, '2', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 0, 394570))
# (58, '023e9d44-96ae-4eed-b912-244ee8c3b994', 2, '8', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 0, 440100))
# (59, '5b2a14e8-6e59-479c-80e3-4696e8980152', 3, 'bacon', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 0, 503700))
# (60, '7b5377b0-3f38-4103-8ad2-90fe89864c04', 1, '563.9', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 0, 557050))
# (61, 'a26649c6-1cb2-470a-871e-6910c64c3e53', 3, '116', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 0, 601944))
# (62, 'cabe07ed-9eca-40ea-8ead-410ef5e83f91', 1, 'Louvrier', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 0, 651741))
# (63, 'e142056d-56ab-4352-b091-b56054bd1359', 3, '16000', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 0, 695950))
# (64, '33d8ea3b-6c6b-4ff1-803d-7e270dea8a57', 3, '2', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 0, 744604))
# (65, '2b3ef98c-cc05-450b-a719-711aee40ac65', 1, 'To be or not to be that is the question whether tis nobler in the mind to suffer the slings and arrows of outrageous fortune', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 0, 789783))
# (66, '366e2f2b-8632-4ef2-81eb-bc3877489217', 2, "Shelley's place", True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 0, 836406))
# (67, '8b3379c0-0981-4f5b-8407-6444610cb212', 1, '1.8', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 0, 880849))
# (68, '366e2f2b-8632-4ef2-81eb-bc3877489217', 1, "Shelley's place", True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 0, 925527))
# (69, 'b4cc024b-3f5e-480e-b96a-6656493255b5', 3, 'Russian-German Legion', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 0, 965906))
# (70, '56137764-b4e0-45b8-9c52-1866420c3df5', 1, 'Li Peng', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 1, 9680))
# (71, 'e29834fd-413a-455c-a33e-c3915b07401c', 1, '21', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 1, 55494))
# (72, '42576abe-0deb-4869-8c63-225c2d75a95a', 3, 'Maktay mato apple', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 1, 95315))
# (73, '14569e28-c88c-43e4-8c32-097d35b9a67d', 1, 'backtick', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 1, 144369))
# (74, 'a0068077-79f4-461a-adfe-75c1a4148545', 2, '90', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 1, 189409))
# (75, '65638e28-7f37-4fa7-b7b9-8c19bb609879', 3, 'Kleinpaul', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 1, 231265))
# (76, '0ff53813-3367-4f43-bcbd-3fd725c1bf4b', 1, 'beta geometric', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 1, 276135))
# (77, '708b99c5-e4a7-49cb-a5cf-933c8d46470d', 1, 'Citations', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 1, 324987))
# (78, '2dfc4c37-fec1-4518-84a7-10095d30ad75', 1, '6', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 1, 370660))
# (79, '4d51c4bf-4b0e-4f3d-897b-3f6687a7d9f2', 1, '8', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 1, 414539))
# (80, '0ff53813-3367-4f43-bcbd-3fd725c1bf4b', 1, 'beta geometric', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 1, 459884))
# (81, 'b4cc024b-3f5e-480e-b96a-6656493255b5', 1, 'Russian-German Legion', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 1, 500088))
# (82, '17b5a6a3-bc87-42e8-b0fb-6ab0781ef2cc', 2, '34689', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 1, 546362))
# (83, 'c3a79cfe-8206-451f-aca8-3fec8ebe51d3', 3, '8', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 1, 589230))
# (84, '42576abe-0deb-4869-8c63-225c2d75a95a', 1, 'Maktay mato apple', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 1, 635743))
# (85, '72c06643-a2fa-4186-aa5c-9ec33ae9b445', 1, '55', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 1, 681164))
# (86, 'd0633230-7067-47a9-9dbf-ee11e0a2cdd6', 2, 'BaseLabelPropagation', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 1, 725652))
# (87, '9d191bce-651d-4746-be2d-7ef8ecadb9c2', 3, 'Extremely', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 1, 770966))
# (88, '7a4a336d-dcfa-45a0-b014-824c7619e8de', 1, '1:41.614', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 1, 824680))
# (89, '853c8244-429e-46ca-89f2-addf40dfb2bd', 3, '11', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 1, 868914))
# (90, 'd0633230-7067-47a9-9dbf-ee11e0a2cdd6', 1, 'BaseLabelPropagation', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 1, 913774))
# (91, 'ad2b4d70-9314-4fe6-bfbe-894a45f6055f', 3, 'War is not here this is a land of peace', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 1, 958242))
# (92, 'b816bfce-3d80-4913-a07d-69b752ce6377', 2, 'fluffy', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 2, 8750))
# (93, '2a649bb1-795f-4a01-b3be-9a01868dae73', 2, '3.1.3.1; 1.11.1.7', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 2, 53346))
# (94, 'e9a2c537-8232-4c3f-85b0-b52de6bcba99', 2, '7', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 2, 98710))
# (95, '87c610df-bef7-4932-b950-1d83ef4e282b', 1, 'Morarji Desai', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 2, 143341))
# (96, '544b7f0c-173a-4377-8d56-57b36eb26ddf', 3, 'A Nightmare on Elm Street', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 2, 192710))
# (97, '853c8244-429e-46ca-89f2-addf40dfb2bd', 2, '11', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 2, 238743))
# (98, '0bb3b44a-ede5-4db5-a520-4e844b0079c5', 2, '536', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 2, 284369))
# (99, 'cca530fc-4052-43b2-b130-b30968d8aa44', 3, 'Rd5', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 2, 330187))
# (100, '3ff6b7a9-a5bd-4412-ad92-0cd0d45c0fee', 2, '56000', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 2, 382604))
# (101, '3ff6b7a9-a5bd-4412-ad92-0cd0d45c0fee', 3, '56000', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 2, 422859))
# (102, '99c9cc74-fdc8-46c6-8f8d-3ce2d3bfeea3', 3, 'cornstarch, freshly squeezed lemon juice, granulated sugar, pure vanilla extract, ripe strawberries', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 2, 467646))
# (103, '5f982798-16b9-4051-ab57-cfc7ebdb2a91', 2, '0.2', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 2, 512557))
# (104, '114d5fd0-e2ae-4b6d-a65a-870da2d19c08', 2, '4', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 2, 552246))
# (105, 'e4e91f1c-1dcd-439e-9fdd-cb976f5293fd', 1, 'cloak', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 2, 602558))
# (106, '0a65cb96-cb6e-4a6a-8aae-c1084f613456', 2, 'Holabird', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 2, 658788))
# (107, '0a65cb96-cb6e-4a6a-8aae-c1084f613456', 2, 'Holabird', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 2, 707323))
# (108, 'c526d8d6-5987-4da9-b24c-83466fa172f3', 2, '0.0424', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 2, 751967))
# (109, '305ac316-eef6-4446-960a-92d80d542f82', 1, 'Wojciech', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 2, 796938))
# (110, 'f0f46385-fc03-4599-b5d3-f56496c3e69f', 2, 'Indonesia, Myanmar', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 2, 851234))
# (111, '4d51c4bf-4b0e-4f3d-897b-3f6687a7d9f2', 2, '8', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 2, 896024))
# (112, '8f80e01c-1296-4371-9486-bb3d68651a60', 3, '90', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 2, 940916))
# (113, 'b7f857e4-d8aa-4387-af2a-0e844df5b9d8', 2, '47', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 2, 986254))
# (114, 'c61d22de-5f6c-4958-a7f6-5e9707bd3466', 2, 'egalitarian', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 3, 31753))
# (115, '50ad0280-0819-4bd9-b275-5de32d3b5bcb', 3, 'The seagull glided peacefully to my chair.', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 3, 72192))
# (116, 'f46b4380-207e-4434-820b-f32ce04ae2a4', 3, 'Harbinger, Tidal', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 3, 117140))
# (117, 'a26649c6-1cb2-470a-871e-6910c64c3e53', 1, '116', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 3, 157127))
# (118, '1dcc160f-c187-48c2-b68e-319bd4354f3d', 3, '3', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 3, 197099))
# (119, 'a7feb290-76bb-4cb7-8800-7edaf7954f2f', 1, '31', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 3, 237732))
# (120, 'ad37a656-079a-49f9-a493-7b739c9167d1', 1, 'Bravo', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 3, 286837))
# (121, '56137764-b4e0-45b8-9c52-1866420c3df5', 2, 'Li Peng', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 3, 327251))
# (122, 'f3917a3d-1d17-4ee2-90c5-683b072218fe', 3, '2732', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 3, 367290))
# (123, '983bba7c-c092-455f-b6c9-7857003d48fc', 3, 'mice', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 3, 413792))
# (124, '50ad0280-0819-4bd9-b275-5de32d3b5bcb', 3, 'The seagull glided peacefully to my chair.', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 3, 458203))
# (125, '1dcc160f-c187-48c2-b68e-319bd4354f3d', 1, '3', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 3, 503419))
# (126, '8f80e01c-1296-4371-9486-bb3d68651a60', 1, '90', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 3, 548311))
# (127, '4d0aa727-86b1-406b-9b33-f870dd14a4a5', 2, '1 in 3', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 3, 593296))
# (128, '872bfbb1-9ccf-49f6-8c5f-aa22818ccd66', 1, 'pears, bananas', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 3, 637497))
# (129, '7619a514-5fa8-43ef-9143-83b66a43d7a4', 2, '04/15/18', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 3, 682179))
# (130, 'cabe07ed-9eca-40ea-8ead-410ef5e83f91', 2, 'Louvrier', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 3, 726826))
# (131, '00d579ea-0889-4fd9-a771-2c8d79835c8d', 2, 'Claude Shannon', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 3, 771799))
# (132, '3ff6b7a9-a5bd-4412-ad92-0cd0d45c0fee', 3, '56000', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 3, 817575))
# (133, '9318445f-fe6a-4e1b-acbf-c68228c9906a', 2, '3/4,1/4,3/4,3/4,2/4,1/2,5/35,7/21,30/5,30/5,3/4,1/15,1/3,4/9,1/8,32/23,103/170', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 3, 863970))
# (134, '56137764-b4e0-45b8-9c52-1866420c3df5', 2, 'Li Peng', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 3, 907503))
# (135, '87c610df-bef7-4932-b950-1d83ef4e282b', 1, 'Morarji Desai', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 3, 952807))
# (136, '676e5e31-a554-4acc-9286-b60d90a92d26', 3, '86', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 4, 5947))
# (137, '5d0080cb-90d7-4712-bc33-848150e917d3', 2, '0.1777', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 51273))
# (138, '7bd855d8-463d-4ed5-93ca-5fe35145f733', 1, '89706.00', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 99272))
# (139, 'c714ab3a-da30-4603-bacd-d008800188b9', 1, '100', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 150037))
# (140, 'bfcd99e1-0690-4b53-a85c-0174a8629083', 1, '17', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 194770))
# (141, '27d5d136-8563-469e-92bf-fd103c28b57c', 1, '(¬A → B) ↔ (A ∨ ¬B)', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 4, 244944))
# (142, '56db2318-640f-477a-a82f-bc93ad13e882', 3, '7, 9', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 4, 289922))
# (143, '11af4e1a-5f45-467d-9aeb-46f4bb0bf034', 2, '6', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 4, 343470))
# (144, '56137764-b4e0-45b8-9c52-1866420c3df5', 3, 'Li Peng', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 4, 388527))
# (145, '5d0080cb-90d7-4712-bc33-848150e917d3', 3, '0.1777', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 432146))
# (146, 'da52d699-e8d2-4dc5-9191-a2199e0b6a9b', 3, 'Out of the Silent Planet', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 4, 477012))
# (147, '7bd855d8-463d-4ed5-93ca-5fe35145f733', 1, '89706.00', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 522073))
# (148, '0ff53813-3367-4f43-bcbd-3fd725c1bf4b', 3, 'beta geometric', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 567608))
# (149, '0bdb7c40-671d-4ad1-9ce3-986b159c0ddc', 1, 'White; 5876', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 613702))
# (150, 'd0633230-7067-47a9-9dbf-ee11e0a2cdd6', 2, 'BaseLabelPropagation', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 4, 658006))
# (151, '3f57289b-8c60-48be-bd80-01f8099ca449', 2, '519', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 703558))
# (152, '99c9cc74-fdc8-46c6-8f8d-3ce2d3bfeea3', 2, 'cornstarch, freshly squeezed lemon juice, granulated sugar, pure vanilla extract, ripe strawberries', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 4, 748521))
# (153, '2b3ef98c-cc05-450b-a719-711aee40ac65', 3, 'To be or not to be that is the question whether tis nobler in the mind to suffer the slings and arrows of outrageous fortune', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 4, 795258))
# (154, 'cca70ce6-1952-45d2-acd4-80c903b0bc49', 1, '85', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 4, 837308))
# (155, '708b99c5-e4a7-49cb-a5cf-933c8d46470d', 1, 'Citations', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 882392))
# (156, 'a26649c6-1cb2-470a-871e-6910c64c3e53', 3, '116', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 4, 926827))
# (157, '389793a7-ca17-4e82-81cb-2b3a2391b4b9', 3, '3', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 4, 971649))
# (158, 'cca530fc-4052-43b2-b130-b30968d8aa44', 1, 'Rd5', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 5, 13045))
# (159, '48eb8242-1099-4c26-95d4-ef22b002457a', 3, '6', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 5, 58999))
# (160, 'ebbc1f13-d24d-40df-9068-adcf735b4240', 3, 'The World of the Twenty First Century', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 5, 102746))
# (161, '0a3cd321-3e76-4622-911b-0fda2e5d6b1a', 3, 'Brunei, China, Morocco, Singapore', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 5, 147660))
# (162, '076c8171-9b3b-49b9-a477-244d2a532826', 3, 'Finance', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 5, 192376))
# (163, '42576abe-0deb-4869-8c63-225c2d75a95a', 2, 'Maktay mato apple', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 5, 237834))
# (164, '0e9e85b8-52b9-4de4-b402-5f635ab9631f', 1, '1927', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 5, 282230))
# (165, '676e5e31-a554-4acc-9286-b60d90a92d26', 2, '86', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 5, 327698))
# (166, 'b7f857e4-d8aa-4387-af2a-0e844df5b9d8', 3, '47', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 5, 372227))
# (167, 'b2c257e0-3ad7-4f05-b8e3-d9da973be36e', 2, '+4.6', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 5, 417868))
# (168, '67e8878b-5cef-4375-804e-e6291fdbe78a', 3, 'Hotels', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 5, 464477))
# (169, '366e2f2b-8632-4ef2-81eb-bc3877489217', 2, "Shelley's place", False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 5, 512062))
# (170, 'b816bfce-3d80-4913-a07d-69b752ce6377', 1, 'fluffy', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 5, 565537))
# (171, '08cae58d-4084-4616-b6dd-dd6534e4825b', 2, '2018', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 5, 619544))
# (172, 'ad2b4d70-9314-4fe6-bfbe-894a45f6055f', 2, 'War is not here this is a land of peace', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 5, 664285))
# (173, '08cae58d-4084-4616-b6dd-dd6534e4825b', 2, '2018', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 5, 708664))
# (174, '6f37996b-2ac7-44b0-8e68-6d28256631b4', 3, 'b, e', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 5, 754167))
# (175, '384d0dd8-e8a4-4cfe-963c-d37f256e7662', 1, '4192', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 5, 797614))
# (176, '1f975693-876d-457b-a649-393859e79bf3', 2, '132, 133, 134, 197, 245', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 5, 845055))
# (177, '5188369a-3bbe-43d8-8b94-11558f909a08', 2, 'Annie Levin', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 5, 889615))
# (178, 'b7f857e4-d8aa-4387-af2a-0e844df5b9d8', 1, '47', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 5, 934950))
# (179, '0e9e85b8-52b9-4de4-b402-5f635ab9631f', 2, '1927', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 5, 979972))
# (180, '16d825ff-1623-4176-a5b5-42e0f5c2b0ac', 1, '6:41 PM', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 6, 23394))
# (181, '73c1b9fe-ee1d-4cf4-96ca-35c08f97b054', 3, '1954', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 6, 68910))
# (182, '6359a0b1-8f7b-499b-9336-840f9ab90688', 2, '39', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 6, 113571))
# (183, '9e1fc53b-46ff-49a1-9d05-9e6faac34cc5', 3, 'Death Knight, Hunter, Paladin, Priest, Warlock', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 6, 158435))
# (184, '624cbf11-6a41-4692-af9c-36b3e5ca3130', 3, 'So we had to let it die.', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 6, 203377))
# (185, 'a3fbeb63-0e8c-4a11-bff6-0e3b484c3e9c', 1, '4', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 6, 248781))
# (186, 'dc28cf18-6431-458b-83ef-64b3ce566c10', 3, '2', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 6, 299794))
# (187, 'd0633230-7067-47a9-9dbf-ee11e0a2cdd6', 2, 'BaseLabelPropagation', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 6, 343156))
# (188, '076c8171-9b3b-49b9-a477-244d2a532826', 2, 'Finance', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 6, 398533))
# (189, 'c526d8d6-5987-4da9-b24c-83466fa172f3', 2, '0.0424', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 6, 442311))
# (190, '935e2cff-ae78-4218-b3f5-115589b19dae', 3, 'research', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 6, 487236))
# (191, '32102e3e-d12a-4209-9163-7b3a104efe5d', 2, 'Time-Parking 2: Parallel Universe', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 6, 540712))
# (192, 'cffe0e32-c9a6-4c52-9877-78ceb4aaa9fb', 2, 'Fred', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 6, 590705))
# (193, 'c365c1c7-a3db-4d5e-a9a1-66f56eae7865', 1, 'Braintree, Honolulu', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 6, 635407))
# (194, 'e29834fd-413a-455c-a33e-c3915b07401c', 2, '21', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 6, 689138))
# (195, '50ad0280-0819-4bd9-b275-5de32d3b5bcb', 2, 'The seagull glided peacefully to my chair.', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 6, 730046))
# (196, '5b2a14e8-6e59-479c-80e3-4696e8980152', 1, 'bacon', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 6, 775052))
# (197, '5188369a-3bbe-43d8-8b94-11558f909a08', 2, 'Annie Levin', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 6, 822908))
# (198, '87c610df-bef7-4932-b950-1d83ef4e282b', 1, 'Morarji Desai', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 6, 869044))
# (199, '46719c30-f4c3-4cad-be07-d5cb21eee6bb', 2, 'Mapping Human Oriented Information to Software Agents for Online Systems Usage', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 6, 913908))
# (200, 'e9a2c537-8232-4c3f-85b0-b52de6bcba99', 2, '7', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 6, 958478))
# (201, '0ff53813-3367-4f43-bcbd-3fd725c1bf4b', 3, 'beta geometric', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 6, 998957))
# (202, '08c0b6e9-1b43-4c2e-ae55-4e3fce2c2715', 2, 'orange, white', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 44243))
# (203, '0b260a57-3f3a-4405-9f29-6d7a1012dbfb', 1, '0.269', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 90059))
# (204, '935e2cff-ae78-4218-b3f5-115589b19dae', 2, 'research', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 7, 134565))
# (205, 'db4fd70a-2d37-40ea-873f-9433dc5e301f', 2, '10', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 7, 180083))
# (206, 'e961a717-6b25-4175-8a68-874d28190ee4', 2, '12', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 224429))
# (207, 'e1fc63a2-da7a-432f-be78-7c4a95598703', 2, '17', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 273001))
# (208, '6359a0b1-8f7b-499b-9336-840f9ab90688', 1, '39', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 317689))
# (209, '935e2cff-ae78-4218-b3f5-115589b19dae', 2, 'research', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 7, 363205))
# (210, '72e110e7-464c-453c-a309-90a95aed6538', 2, 'Guatemala', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 7, 408472))
# (211, '2a649bb1-795f-4a01-b3be-9a01868dae73', 1, '3.1.3.1; 1.11.1.7', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 453153))
# (212, 'e1fc63a2-da7a-432f-be78-7c4a95598703', 1, '17', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 498859))
# (213, 'cca70ce6-1952-45d2-acd4-80c903b0bc49', 2, '85', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 7, 548179))
# (214, '0bdb7c40-671d-4ad1-9ce3-986b159c0ddc', 1, 'White; 5876', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 7, 594164))
# (215, '04a04a9b-226c-43fd-b319-d5e89743676f', 1, '41', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 7, 636653))
# (216, 'e2d69698-bc99-4e85-9880-67eaccd66e6c', 3, 'Michele Fitzgerald', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 681282))
# (217, '851e570a-e3de-4d84-bcfa-cc85578baa59', 1, 'Briniest', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 725448))
# (218, 'b2c257e0-3ad7-4f05-b8e3-d9da973be36e', 3, '+4.6', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 7, 780231))
# (219, '3da89939-209c-4086-8520-7eb734e6b4ef', 3, '8, 29, 22, 1, 8, 26', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 7, 823426))
# (220, '0e9e85b8-52b9-4de4-b402-5f635ab9631f', 3, '1927', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 868825))
# (221, 'e8cb5b03-41e0-4086-99e5-f6806cd97211', 1, 'shrimp', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 914062))
# (222, '56137764-b4e0-45b8-9c52-1866420c3df5', 1, 'Li Peng', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 7, 958588))
# (223, '14569e28-c88c-43e4-8c32-097d35b9a67d', 1, 'backtick', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 8, 13514))
# (224, '7cc4acfa-63fd-4acc-a1a1-e8e529e0a97f', 2, 'Wharvton', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 61906))
# (225, 'd0633230-7067-47a9-9dbf-ee11e0a2cdd6', 1, 'BaseLabelPropagation', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 8, 108245))
# (226, '0b260a57-3f3a-4405-9f29-6d7a1012dbfb', 3, '0.269', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 152447))
# (227, '076c8171-9b3b-49b9-a477-244d2a532826', 1, 'Finance', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 202469))
# (228, 'bda648d7-d618-4883-88f4-3466eabd860e', 3, 'Saint Petersburg', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 8, 247065))
# (229, '0a65cb96-cb6e-4a6a-8aae-c1084f613456', 1, 'Holabird', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 8, 300629))
# (230, 'e1fc63a2-da7a-432f-be78-7c4a95598703', 3, '17', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 8, 346190))
# (231, '305ac316-eef6-4446-960a-92d80d542f82', 2, 'Wojciech', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 390027))
# (232, 'b4cc024b-3f5e-480e-b96a-6656493255b5', 2, 'Russian-German Legion', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 435883))
# (233, '023e9d44-96ae-4eed-b912-244ee8c3b994', 1, '8', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 8, 485544))
# (234, '50f58759-7bd6-406f-9b0d-5692beb2a926', 1, '3', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 8, 529857))
# (235, 'ad37a656-079a-49f9-a493-7b739c9167d1', 2, 'Bravo', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 8, 579505))
# (236, '2dfc4c37-fec1-4518-84a7-10095d30ad75', 2, '6', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 8, 623114))
# (237, '389793a7-ca17-4e82-81cb-2b3a2391b4b9', 1, '3', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 8, 668235))
# (238, 'ad37a656-079a-49f9-a493-7b739c9167d1', 3, 'Bravo', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 8, 721906))
# (239, 'a3fbeb63-0e8c-4a11-bff6-0e3b484c3e9c', 1, '4', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 767445))
# (240, '0a3cd321-3e76-4622-911b-0fda2e5d6b1a', 1, 'Brunei, China, Morocco, Singapore', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 8, 813371))
# (241, 'f2feb6a4-363c-4c09-a804-0db564eafd68', 2, '900000', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 858241))
# (242, '73c1b9fe-ee1d-4cf4-96ca-35c08f97b054', 2, '1954', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 903773))
# (243, 'c714ab3a-da30-4603-bacd-d008800188b9', 2, '100', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 948257))
# (244, 'e2d69698-bc99-4e85-9880-67eaccd66e6c', 3, 'Michele Fitzgerald', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 8, 992997))
# (245, 'ecbc4f94-95a3-4cc7-b255-6741a458a625', 3, '13', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 9, 36951))
# (246, '305ac316-eef6-4446-960a-92d80d542f82', 2, 'Wojciech', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 9, 82487))
# (247, 'd700d50d-c707-4dca-90dc-4528cddd0c80', 1, 'Roger Miller', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 9, 127874))
# (248, '305ac316-eef6-4446-960a-92d80d542f82', 1, 'Wojciech', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 9, 171831))
# (249, 'b816bfce-3d80-4913-a07d-69b752ce6377', 2, 'fluffy', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 9, 218777))
# (250, '3f57289b-8c60-48be-bd80-01f8099ca449', 3, '519', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 9, 262331))
# (251, 'a0c07678-e491-4bbc-8f0b-07405144218f', 2, 'Yoshida, Uehara', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 9, 306862))
# (252, '54612da3-fd56-4941-80f4-5eb82330de25', 3, '60', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 9, 356968))
# (253, 'f2feb6a4-363c-4c09-a804-0db564eafd68', 1, '900000', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 9, 401583))
# (254, '71345b0a-9c7d-4b50-b2bf-937ec5879845', 1, 'Here be dragons', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 9, 447485))
# (255, '384d0dd8-e8a4-4cfe-963c-d37f256e7662', 3, '4192', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 9, 501775))
# (256, '5f982798-16b9-4051-ab57-cfc7ebdb2a91', 3, '0.2', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 9, 554242))
# (257, 'e2d69698-bc99-4e85-9880-67eaccd66e6c', 3, 'Michele Fitzgerald', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 9, 605278))
# (258, '65da0822-a48a-4a68-bbad-8ed1b835a834', 2, 'Santa Clara, Boston', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 9, 650058))
# (259, '8e867cd7-cff9-4e6c-867a-ff5ddc2550be', 1, '3', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 9, 695358))
# (260, '0e9e85b8-52b9-4de4-b402-5f635ab9631f', 3, '1927', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 9, 739991))
# (261, 'bfcd99e1-0690-4b53-a85c-0174a8629083', 2, '17', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 9, 784427))
# (262, 'cca530fc-4052-43b2-b130-b30968d8aa44', 2, 'Rd5', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 9, 826653))
# (263, '20194330-9976-4043-8632-f8485c6c71b2', 3, '4', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 9, 880646))
# (264, 'd5141ca5-e7a0-469f-bf3e-e773507c86e2', 1, '19/02/2009', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 9, 925689))
# (265, '0ff53813-3367-4f43-bcbd-3fd725c1bf4b', 2, 'beta geometric', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 9, 970215))
# (266, 'f2feb6a4-363c-4c09-a804-0db564eafd68', 2, '900000', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 10, 14552))
# (267, '4b6bb5f7-f634-410e-815d-e673ab7f8632', 1, 'THE CASTLE', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 10, 61600))
# (268, '08cae58d-4084-4616-b6dd-dd6534e4825b', 1, '2018', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 10, 104708))
# (269, '9f41b083-683e-4dcf-9185-ccfeaa88fa45', 1, '0', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 10, 149481))
# (270, 'a0c07678-e491-4bbc-8f0b-07405144218f', 1, 'Yoshida, Uehara', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 10, 194756))
# (271, '50f58759-7bd6-406f-9b0d-5692beb2a926', 3, '3', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 10, 242052))
# (272, '6b078778-0b90-464d-83f6-59511c811b01', 2, 'Alfonso Visconti', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 10, 284857))
# (273, 'f0f46385-fc03-4599-b5d3-f56496c3e69f', 1, 'Indonesia, Myanmar', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 10, 330288))
# (274, '676e5e31-a554-4acc-9286-b60d90a92d26', 1, '86', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 10, 375979))
# (275, 'a26649c6-1cb2-470a-871e-6910c64c3e53', 3, '116', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 10, 419767))
# (276, '5d0080cb-90d7-4712-bc33-848150e917d3', 2, '0.1777', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 10, 463780))
# (277, '3f57289b-8c60-48be-bd80-01f8099ca449', 3, '519', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 10, 508678))
# (278, 'da52d699-e8d2-4dc5-9191-a2199e0b6a9b', 3, 'Out of the Silent Planet', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 10, 554279))
# (279, 'c8b7e059-c60d-472e-ad64-3b04ae1166dc', 1, '8', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 10, 599480))
# (280, '9e1fc53b-46ff-49a1-9d05-9e6faac34cc5', 1, 'Death Knight, Hunter, Paladin, Priest, Warlock', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 10, 645474))
# (281, '8b3379c0-0981-4f5b-8407-6444610cb212', 2, '1.8', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 10, 690861))
# (282, '72c06643-a2fa-4186-aa5c-9ec33ae9b445', 2, '55', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 10, 735149))
# (283, '87c610df-bef7-4932-b950-1d83ef4e282b', 1, 'Morarji Desai', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 10, 780001))
# (284, '3da89939-209c-4086-8520-7eb734e6b4ef', 2, '8, 29, 22, 1, 8, 26', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 10, 823326))
# (285, '14569e28-c88c-43e4-8c32-097d35b9a67d', 3, 'backtick', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 10, 873083))
# (286, 'f2feb6a4-363c-4c09-a804-0db564eafd68', 3, '900000', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 10, 918921))
# (287, '3f57289b-8c60-48be-bd80-01f8099ca449', 1, '519', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 10, 963105))
# (288, '0383a3ee-47a7-41a4-b493-519bdefe0488', 3, 'Rockhopper penguin', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 11, 8094))
# (289, 'b7f857e4-d8aa-4387-af2a-0e844df5b9d8', 2, '47', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 11, 53487))
# (290, '73c1b9fe-ee1d-4cf4-96ca-35c08f97b054', 1, '1954', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 11, 98867))
# (291, 'ed58682d-bc52-4baa-9eb0-4eb81e1edacc', 3, 'stare', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 11, 143084))
# (292, '7673d772-ef80-4f0f-a602-1bf4485c9b43', 1, 'inference', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 11, 188250))
# (293, '366e2f2b-8632-4ef2-81eb-bc3877489217', 2, "Shelley's place", True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 11, 232784))
# (294, 'da52d699-e8d2-4dc5-9191-a2199e0b6a9b', 1, 'Out of the Silent Planet', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 11, 277884))
# (295, '6f37996b-2ac7-44b0-8e68-6d28256631b4', 2, 'b, e', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 11, 323181))
# (296, '8f80e01c-1296-4371-9486-bb3d68651a60', 1, '90', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 11, 369052))
# (297, '3f57289b-8c60-48be-bd80-01f8099ca449', 3, '519', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 11, 412952))
# (298, '9d191bce-651d-4746-be2d-7ef8ecadb9c2', 3, 'Extremely', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 11, 458022))
# (299, '00d579ea-0889-4fd9-a771-2c8d79835c8d', 3, 'Claude Shannon', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 11, 498432))
# (300, '2d83110e-a098-4ebb-9987-066c06fa42d0', 2, 'Right', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 11, 543840))
# (301, '935e2cff-ae78-4218-b3f5-115589b19dae', 2, 'research', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 11, 588707))
# (302, 'b4cc024b-3f5e-480e-b96a-6656493255b5', 1, 'Russian-German Legion', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 11, 632873))
# (303, 'ebbc1f13-d24d-40df-9068-adcf735b4240', 2, 'The World of the Twenty First Century', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 11, 682771))
# (304, '54612da3-fd56-4941-80f4-5eb82330de25', 3, '60', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 11, 726746))
# (305, 'ad37a656-079a-49f9-a493-7b739c9167d1', 3, 'Bravo', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 11, 777942))
# (306, '0e9e85b8-52b9-4de4-b402-5f635ab9631f', 2, '1927', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 11, 822792))
# (307, 'cca530fc-4052-43b2-b130-b30968d8aa44', 1, 'Rd5', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 11, 874731))
# (308, 'f918266a-b3e0-4914-865d-4faa564f1aef', 3, '0', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 11, 919483))
# (309, 'ad2b4d70-9314-4fe6-bfbe-894a45f6055f', 3, 'War is not here this is a land of peace', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 11, 964263))
# (310, 'd5141ca5-e7a0-469f-bf3e-e773507c86e2', 2, '19/02/2009', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 12, 14003))
# (311, '14569e28-c88c-43e4-8c32-097d35b9a67d', 1, 'backtick', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 12, 63927))
# (312, '4d51c4bf-4b0e-4f3d-897b-3f6687a7d9f2', 3, '8', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 12, 103817))
# (313, '8b3379c0-0981-4f5b-8407-6444610cb212', 2, '1.8', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 12, 162961))
# (314, '2d83110e-a098-4ebb-9987-066c06fa42d0', 2, 'Right', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 12, 206872))
# (315, 'bda648d7-d618-4883-88f4-3466eabd860e', 3, 'Saint Petersburg', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 12, 254114))
# (316, '4b6bb5f7-f634-410e-815d-e673ab7f8632', 1, 'THE CASTLE', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 12, 306872))
# (317, '50f58759-7bd6-406f-9b0d-5692beb2a926', 3, '3', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 12, 362335))
# (318, '076c8171-9b3b-49b9-a477-244d2a532826', 3, 'Finance', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 12, 414936))
# (319, 'e4e91f1c-1dcd-439e-9fdd-cb976f5293fd', 3, 'cloak', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 12, 459882))
# (320, 'd5141ca5-e7a0-469f-bf3e-e773507c86e2', 2, '19/02/2009', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 12, 504764))
# (321, '872bfbb1-9ccf-49f6-8c5f-aa22818ccd66', 1, 'pears, bananas', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 12, 550062))
# (322, 'b7f857e4-d8aa-4387-af2a-0e844df5b9d8', 2, '47', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 12, 597184))
# (323, '87c610df-bef7-4932-b950-1d83ef4e282b', 1, 'Morarji Desai', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 12, 640038))
# (324, '7dd30055-0198-452e-8c25-f73dbe27dcb8', 3, '1.456', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 12, 684907))
# (325, '2dfc4c37-fec1-4518-84a7-10095d30ad75', 1, '6', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 12, 730902))
# (326, 'a1e91b78-d3d8-4675-bb8d-62741b4b68a6', 2, '3', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 12, 775483))
# (327, '5b2a14e8-6e59-479c-80e3-4696e8980152', 2, 'bacon', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 12, 823105))
# (328, '0383a3ee-47a7-41a4-b493-519bdefe0488', 2, 'Rockhopper penguin', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 12, 868177))
# (329, '8b3379c0-0981-4f5b-8407-6444610cb212', 1, '1.8', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 12, 913429))
# (330, '87c610df-bef7-4932-b950-1d83ef4e282b', 1, 'Morarji Desai', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 12, 958835))
# (331, 'a56f1527-3abf-41d6-91f8-7296d6336c3f', 2, '185', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 13, 3624))
# (332, '4d51c4bf-4b0e-4f3d-897b-3f6687a7d9f2', 2, '8', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 13, 45406))
# (333, '544b7f0c-173a-4377-8d56-57b36eb26ddf', 2, 'A Nightmare on Elm Street', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 13, 89735))
# (334, '0a65cb96-cb6e-4a6a-8aae-c1084f613456', 2, 'Holabird', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 13, 135074))
# (335, '87c610df-bef7-4932-b950-1d83ef4e282b', 2, 'Morarji Desai', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 13, 180225))
# (336, 'e1fc63a2-da7a-432f-be78-7c4a95598703', 2, '17', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 13, 224218))
# (337, '7b5377b0-3f38-4103-8ad2-90fe89864c04', 2, '563.9', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 13, 269232))
# (338, 'cffe0e32-c9a6-4c52-9877-78ceb4aaa9fb', 3, 'Fred', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 13, 313892))
# (339, '4d0aa727-86b1-406b-9b33-f870dd14a4a5', 1, '1 in 3', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 13, 353903))
# (340, 'dc22a632-937f-4e6a-b72f-ba0ff3f5ff97', 2, "Five Hundred Things To Eat Before It's Too Late: and the Very Best Places to Eat Them", False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 13, 407906))
# (341, 'b816bfce-3d80-4913-a07d-69b752ce6377', 1, 'fluffy', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 13, 453831))
# (342, '48eb8242-1099-4c26-95d4-ef22b002457a', 3, '6', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 13, 499992))
# (343, '114d5fd0-e2ae-4b6d-a65a-870da2d19c08', 3, '4', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 13, 551689))
# (344, 'dc22a632-937f-4e6a-b72f-ba0ff3f5ff97', 1, "Five Hundred Things To Eat Before It's Too Late: and the Very Best Places to Eat Them", True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 13, 596769))
# (345, '3ff6b7a9-a5bd-4412-ad92-0cd0d45c0fee', 2, '56000', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 13, 641175))
# (346, '50ad0280-0819-4bd9-b275-5de32d3b5bcb', 3, 'The seagull glided peacefully to my chair.', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 13, 690479))
# (347, 'ec09fa32-d03f-4bf8-84b0-1f16922c3ae4', 2, '3', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 13, 736147))
# (348, 'a1e91b78-d3d8-4675-bb8d-62741b4b68a6', 2, '3', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 13, 780350))
# (349, 'c526d8d6-5987-4da9-b24c-83466fa172f3', 1, '0.0424', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 13, 825520))
# (350, '6b078778-0b90-464d-83f6-59511c811b01', 3, 'Alfonso Visconti', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 13, 871594))
# (351, '5f982798-16b9-4051-ab57-cfc7ebdb2a91', 2, '0.2', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 13, 916938))
# (352, '8131e2c0-0083-4265-9ce7-78c2d568425d', 1, '101.376, 84.348', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 13, 961259))
# (353, '624cbf11-6a41-4692-af9c-36b3e5ca3130', 1, 'So we had to let it die.', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 14, 6250))
# (354, '3627a8be-a77f-41bb-b807-7e1bd4c0ebdf', 2, '142', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 14, 51878))
# ...
# (884, '56db2318-640f-477a-a82f-bc93ad13e882', 1, '7, 9', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 38, 331210))
# (885, '08f3a05f-5947-4089-a4c4-d4bcfaa6b7a0', 3, '2', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 38, 375044))
# (886, '7b5377b0-3f38-4103-8ad2-90fe89864c04', 3, '563.9', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 38, 419522))
# (887, 'c714ab3a-da30-4603-bacd-d008800188b9', 1, '100', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 38, 473491))
# (888, 'a3fbeb63-0e8c-4a11-bff6-0e3b484c3e9c', 1, '4', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 38, 519102))
# (889, '00d579ea-0889-4fd9-a771-2c8d79835c8d', 2, 'Claude Shannon', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 38, 563361))
# (890, '27d5d136-8563-469e-92bf-fd103c28b57c', 3, '(¬A → B) ↔ (A ∨ ¬B)', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 38, 617155))
# (891, 'd5141ca5-e7a0-469f-bf3e-e773507c86e2', 1, '19/02/2009', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 38, 662198))
# (892, '8f80e01c-1296-4371-9486-bb3d68651a60', 2, '90', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 38, 709802))
# (893, '5f982798-16b9-4051-ab57-cfc7ebdb2a91', 3, '0.2', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 38, 755658))
# (894, 'b415aba4-4b68-4fc6-9b89-2c812e55a3e1', 1, 'diamond', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 38, 801216))
# (895, '853c8244-429e-46ca-89f2-addf40dfb2bd', 1, '11', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 38, 846890))
# (896, 'f0f46385-fc03-4599-b5d3-f56496c3e69f', 2, 'Indonesia, Myanmar', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 38, 889525))
# (897, 'f0f46385-fc03-4599-b5d3-f56496c3e69f', 3, 'Indonesia, Myanmar', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 38, 935526))
# (898, 'd1af70ea-a9a4-421a-b9cc-94b5e02f1788', 2, '736455', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 38, 979670))
# (899, '5b2a14e8-6e59-479c-80e3-4696e8980152', 2, 'bacon', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 39, 19198))
# (900, '9f41b083-683e-4dcf-9185-ccfeaa88fa45', 1, '0', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 39, 64467))
# (901, 'c3a79cfe-8206-451f-aca8-3fec8ebe51d3', 2, '8', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 39, 109695))
# (902, '0a3cd321-3e76-4622-911b-0fda2e5d6b1a', 3, 'Brunei, China, Morocco, Singapore', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 39, 154861))
# (903, '08c0b6e9-1b43-4c2e-ae55-4e3fce2c2715', 1, 'orange, white', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 39, 198977))
# (904, 'b415aba4-4b68-4fc6-9b89-2c812e55a3e1', 1, 'diamond', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 39, 244678))
# (905, 'a7feb290-76bb-4cb7-8800-7edaf7954f2f', 2, '31', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 39, 298266))
# (906, '56137764-b4e0-45b8-9c52-1866420c3df5', 1, 'Li Peng', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 39, 348293))
# (907, '08c0b6e9-1b43-4c2e-ae55-4e3fce2c2715', 3, 'orange, white', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 39, 397719))
# (908, '0383a3ee-47a7-41a4-b493-519bdefe0488', 2, 'Rockhopper penguin', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 39, 443008))
# (909, 'b816bfce-3d80-4913-a07d-69b752ce6377', 3, 'fluffy', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 39, 493671))
# (910, '2dfc4c37-fec1-4518-84a7-10095d30ad75', 1, '6', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 39, 584075))
# (911, '16d825ff-1623-4176-a5b5-42e0f5c2b0ac', 2, '6:41 PM', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 39, 630567))
# (912, '389793a7-ca17-4e82-81cb-2b3a2391b4b9', 2, '3', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 39, 696469))
# (913, 'd5141ca5-e7a0-469f-bf3e-e773507c86e2', 3, '19/02/2009', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 39, 765449))
# (914, '8d46b8d6-b38a-47ff-ac74-cda14cf2d19b', 2, '0.00033', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 39, 810181))
# (915, 'b9763138-c053-4832-9f55-86200cb1f99c', 1, '3', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 39, 855001))
# (916, 'ebbc1f13-d24d-40df-9068-adcf735b4240', 2, 'The World of the Twenty First Century', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 39, 907435))
# (917, '65da0822-a48a-4a68-bbad-8ed1b835a834', 3, 'Santa Clara, Boston', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 39, 954661))
# (918, 'cca530fc-4052-43b2-b130-b30968d8aa44', 2, 'Rd5', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 40, 11187))
# (919, 'b2c257e0-3ad7-4f05-b8e3-d9da973be36e', 2, '+4.6', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 40, 105420))
# (920, 'bfcd99e1-0690-4b53-a85c-0174a8629083', 3, '17', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 40, 157056))
# (921, 'c714ab3a-da30-4603-bacd-d008800188b9', 1, '100', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 40, 207358))
# (922, '56137764-b4e0-45b8-9c52-1866420c3df5', 1, 'Li Peng', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 40, 308972))
# (923, '08cae58d-4084-4616-b6dd-dd6534e4825b', 3, '2018', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 40, 357020))
# (924, 'c714ab3a-da30-4603-bacd-d008800188b9', 1, '100', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 40, 403556))
# (925, 'a1e91b78-d3d8-4675-bb8d-62741b4b68a6', 2, '3', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 40, 450801))
# (926, 'ded28325-3447-4c56-860f-e497d6fb3577', 2, 'Picnic is in Ploybius Plaza.', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 40, 512536))
# (927, '56137764-b4e0-45b8-9c52-1866420c3df5', 1, 'Li Peng', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 40, 562478))
# (928, '73c1b9fe-ee1d-4cf4-96ca-35c08f97b054', 3, '1954', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 40, 605726))
# (929, 'c365c1c7-a3db-4d5e-a9a1-66f56eae7865', 3, 'Braintree, Honolulu', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 40, 660963))
# (930, '076c8171-9b3b-49b9-a477-244d2a532826', 1, 'Finance', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 40, 706280))
# (931, 'cca530fc-4052-43b2-b130-b30968d8aa44', 2, 'Rd5', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 40, 772447))
# (932, '851e570a-e3de-4d84-bcfa-cc85578baa59', 3, 'Briniest', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 40, 849499))
# (933, '11af4e1a-5f45-467d-9aeb-46f4bb0bf034', 3, '6', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 40, 914660))
# (934, 'e2d69698-bc99-4e85-9880-67eaccd66e6c', 2, 'Michele Fitzgerald', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 40, 984059))
# (935, '851e570a-e3de-4d84-bcfa-cc85578baa59', 2, 'Briniest', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 41, 44076))
# (936, 'ad37a656-079a-49f9-a493-7b739c9167d1', 3, 'Bravo', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 41, 213828))
# (937, '4fc2f1ae-8625-45b5-ab34-ad4433bc21f8', 1, 'FunkMonk', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 41, 266016))
# (938, '851e570a-e3de-4d84-bcfa-cc85578baa59', 2, 'Briniest', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 41, 317065))
# (939, '023e9d44-96ae-4eed-b912-244ee8c3b994', 1, '8', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 41, 380402))
# (940, 'cf106601-ab4f-4af9-b045-5295fe67b37d', 1, 'CUB', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 41, 453530))
# (941, 'dc22a632-937f-4e6a-b72f-ba0ff3f5ff97', 3, "Five Hundred Things To Eat Before It's Too Late: and the Very Best Places to Eat Them", True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 41, 515774))
# (942, '00d579ea-0889-4fd9-a771-2c8d79835c8d', 2, 'Claude Shannon', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 41, 561099))
# (943, 'd1af70ea-a9a4-421a-b9cc-94b5e02f1788', 2, '736455', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 41, 613158))
# (944, 'f918266a-b3e0-4914-865d-4faa564f1aef', 1, '0', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 41, 659481))
# (945, 'b2c257e0-3ad7-4f05-b8e3-d9da973be36e', 1, '+4.6', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 41, 746579))
# (946, '366e2f2b-8632-4ef2-81eb-bc3877489217', 1, "Shelley's place", True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 41, 807602))
# (947, '00d579ea-0889-4fd9-a771-2c8d79835c8d', 3, 'Claude Shannon', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 41, 861842))
# (948, 'dd3c7503-f62a-4bd0-9f67-1b63b94194cc', 2, '6', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 41, 909944))
# (949, '0a3cd321-3e76-4622-911b-0fda2e5d6b1a', 1, 'Brunei, China, Morocco, Singapore', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 41, 954345))
# (950, '20194330-9976-4043-8632-f8485c6c71b2', 1, '4', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 42, 7488))
# (951, 'dc22a632-937f-4e6a-b72f-ba0ff3f5ff97', 3, "Five Hundred Things To Eat Before It's Too Late: and the Very Best Places to Eat Them", False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 42, 79396))
# (952, '73c1b9fe-ee1d-4cf4-96ca-35c08f97b054', 3, '1954', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 42, 135561))
# (953, 'b415aba4-4b68-4fc6-9b89-2c812e55a3e1', 2, 'diamond', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 42, 198828))
# (954, 'b9763138-c053-4832-9f55-86200cb1f99c', 1, '3', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 42, 249908))
# (955, '9d191bce-651d-4746-be2d-7ef8ecadb9c2', 3, 'Extremely', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 42, 299862))
# (956, 'de9887f5-ead8-4727-876f-5a4078f8598c', 2, '22', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 42, 348552))
# (957, '853c8244-429e-46ca-89f2-addf40dfb2bd', 3, '11', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 42, 413384))
# (958, '023e9d44-96ae-4eed-b912-244ee8c3b994', 3, '8', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 42, 514386))
# (959, '935e2cff-ae78-4218-b3f5-115589b19dae', 3, 'research', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 42, 558213))
# (960, '56db2318-640f-477a-a82f-bc93ad13e882', 3, '7, 9', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 42, 604951))
# (961, '08cae58d-4084-4616-b6dd-dd6534e4825b', 1, '2018', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 42, 664121))
# (962, '5a0c1adf-205e-4841-a666-7c3ef95def9d', 1, 'Claus', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 42, 709674))
# (963, '5f982798-16b9-4051-ab57-cfc7ebdb2a91', 2, '0.2', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 42, 787268))
# (964, 'dc22a632-937f-4e6a-b72f-ba0ff3f5ff97', 1, "Five Hundred Things To Eat Before It's Too Late: and the Very Best Places to Eat Them", False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 42, 841581))
# (965, 'cffe0e32-c9a6-4c52-9877-78ceb4aaa9fb', 1, 'Fred', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 42, 891966))
# (966, 'a56f1527-3abf-41d6-91f8-7296d6336c3f', 2, '185', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 42, 954532))
# (967, 'd5141ca5-e7a0-469f-bf3e-e773507c86e2', 2, '19/02/2009', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 43, 3019))
# (968, 'f2feb6a4-363c-4c09-a804-0db564eafd68', 3, '900000', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 43, 53664))
# (969, '3da89939-209c-4086-8520-7eb734e6b4ef', 3, '8, 29, 22, 1, 8, 26', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 43, 105470))
# (970, 'da52d699-e8d2-4dc5-9191-a2199e0b6a9b', 3, 'Out of the Silent Planet', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 43, 150435))
# (971, '17b5a6a3-bc87-42e8-b0fb-6ab0781ef2cc', 1, '34689', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 43, 199610))
# (972, '6359a0b1-8f7b-499b-9336-840f9ab90688', 1, '39', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 43, 276003))
# (973, '0b260a57-3f3a-4405-9f29-6d7a1012dbfb', 1, '0.269', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 43, 321214))
# (974, 'f918266a-b3e0-4914-865d-4faa564f1aef', 1, '0', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 43, 402108))
# (975, 'c61d22de-5f6c-4958-a7f6-5e9707bd3466', 2, 'egalitarian', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 43, 456520))
# (976, '7cc4acfa-63fd-4acc-a1a1-e8e529e0a97f', 2, 'Wharvton', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 43, 505233))
# (977, '6359a0b1-8f7b-499b-9336-840f9ab90688', 1, '39', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 43, 564475))
# (978, '2dfc4c37-fec1-4518-84a7-10095d30ad75', 3, '6', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 43, 611246))
# (979, '3da89939-209c-4086-8520-7eb734e6b4ef', 1, '8, 29, 22, 1, 8, 26', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 43, 658716))
# (980, 'c714ab3a-da30-4603-bacd-d008800188b9', 1, '100', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 43, 706237))
# (981, 'a0068077-79f4-461a-adfe-75c1a4148545', 1, '90', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 43, 772281))
# (982, 'bec74516-02fc-48dc-b202-55e78d0e17cf', 3, '26.4', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 43, 822159))
# (983, 'e8cb5b03-41e0-4086-99e5-f6806cd97211', 2, 'shrimp', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 43, 870634))
# (984, '389793a7-ca17-4e82-81cb-2b3a2391b4b9', 2, '3', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 43, 918707))
# (985, 'e0c10771-d627-4fd7-9694-05348e54ee36', 3, '234.9', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 44, 8330))
# (986, '99c9cc74-fdc8-46c6-8f8d-3ce2d3bfeea3', 2, 'cornstarch, freshly squeezed lemon juice, granulated sugar, pure vanilla extract, ripe strawberries', False, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 44, 68244))
# (987, 'cf106601-ab4f-4af9-b045-5295fe67b37d', 2, 'CUB', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 44, 122237))
# (988, '14569e28-c88c-43e4-8c32-097d35b9a67d', 1, 'backtick', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 44, 166585))
# (989, '305ac316-eef6-4446-960a-92d80d542f82', 2, 'Wojciech', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 44, 210815))
# (990, '3ff6b7a9-a5bd-4412-ad92-0cd0d45c0fee', 3, '56000', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 44, 264397))
# (991, 'dc28cf18-6431-458b-83ef-64b3ce566c10', 3, '2', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 44, 309649))
# (992, '0383a3ee-47a7-41a4-b493-519bdefe0488', 3, 'Rockhopper penguin', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 44, 354236))
# (993, '20194330-9976-4043-8632-f8485c6c71b2', 3, '4', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 44, 399327))
# (994, '7b5377b0-3f38-4103-8ad2-90fe89864c04', 1, '563.9', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 44, 446497))
# (995, 'e4e91f1c-1dcd-439e-9fdd-cb976f5293fd', 1, 'cloak', False, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 44, 489361))
# (996, 'e8cb5b03-41e0-4086-99e5-f6806cd97211', 2, 'shrimp', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 44, 536327))
# (997, '0383a3ee-47a7-41a4-b493-519bdefe0488', 2, 'Rockhopper penguin', False, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 44, 583628))
# (998, '5188369a-3bbe-43d8-8b94-11558f909a08', 3, 'Annie Levin', True, 'Helpless!', datetime.datetime(2024, 9, 24, 18, 26, 44, 626848))
# (999, 'ebbc1f13-d24d-40df-9068-adcf735b4240', 1, 'The World of the Twenty First Century', True, 'AS IS', datetime.datetime(2024, 9, 24, 18, 26, 44, 671731))
# (1000, '7a4a336d-dcfa-45a0-b014-824c7619e8de', 2, '1:41.614', True, 'With Annotation', datetime.datetime(2024, 9, 24, 18, 26, 44, 730819))

# %%
from sqlalchemy import create_engine, MetaData, func, case
from sqlalchemy.orm import sessionmaker

# # Create SQLAlchemy engine
# DATABASE_URL = f"postgresql+psycopg2://admin:Password@35.243.210.8:5432/assignment-1-postgres"
# engine = create_engine(DATABASE_URL)

# # Create MetaData instance
# metadata = MetaData()

# Explicitly reflect the tables
#metadata.reflect(bind=engine)

# Check if 'llmresponses' table is in the metadata
if 'llmresponses' not in metadata.tables:
    print("Error: 'llmresponses' table not found!")
else:
    # Function to calculate overall accuracy per LLM
    def overall_accuracy_per_llm():
        Session = sessionmaker(bind=engine)
        session = Session()

        llmresponses_table = metadata.tables['llmresponses']

        query = session.query(
            llmresponses_table.c.llmid,
            (func.count(case(
                (llmresponses_table.c.isannotated == False, llmresponses_table.c.responseid)
            )) / func.count(func.distinct(llmresponses_table.c.taskid)) * 100).label("accuracy_percentage")
        ).filter(
            llmresponses_table.c.resultcategory == 'AS IS'
        ).group_by(llmresponses_table.c.llmid)

        print("Overall Accuracy per LLM (As Is):")
        for row in query.all():
            print(f"LLM ID: {row[0]}, Accuracy: {row[1]:.2f}%")

        session.close()

    # Call the function
    overall_accuracy_per_llm()
# Out:
# Overall Accuracy per LLM (As Is):
# LLM ID: 1, Accuracy: 67.95%
# LLM ID: 2, Accuracy: 60.47%
# LLM ID: 3, Accuracy: 78.75%

# %%
def accuracy_with_annotation():
    Session = sessionmaker(bind=engine)
    session = Session()

    llmresponses_table = metadata.tables['llmresponses']

    query = session.query(
        llmresponses_table.c.llmid,
        (func.count(case(
            (llmresponses_table.c.isannotated == True, llmresponses_table.c.responseid)
        )) / func.count(func.distinct(llmresponses_table.c.taskid)) * 100).label("accuracy_with_annotation")
    ).filter(
        llmresponses_table.c.resultcategory == 'With Annotation'
    ).group_by(llmresponses_table.c.llmid)

    print("\nAccuracy with Annotation:")
    for row in query.all():
        print(f"LLM ID: {row[0]}, Accuracy with Annotation: {row[1]:.2f}%")

    session.close()

# Call the function
accuracy_with_annotation()
# Out:
# Accuracy with Annotation:
# LLM ID: 1, Accuracy with Annotation: 66.67%
# LLM ID: 2, Accuracy with Annotation: 82.14%
# LLM ID: 3, Accuracy with Annotation: 65.82%

# %%
def improvement_rate():
    Session = sessionmaker(bind=engine)
    session = Session()

    llmresponses_table = metadata.tables['llmresponses']

    query = session.query(
        llmresponses_table.c.llmid,
        (func.count(case(
            (llmresponses_table.c.resultcategory == 'With Annotation', llmresponses_table.c.responseid)
        )) / func.count(case(
            (llmresponses_table.c.resultcategory != 'AS IS', llmresponses_table.c.responseid)
        )) * 100).label("improvement_rate")
    ).group_by(llmresponses_table.c.llmid)

    print("\nImprovement Rate:")
    for row in query.all():
        print(f"LLM ID: {row[0]}, Improvement Rate: {row[1]:.2f}%")

    session.close()

# Call the function
improvement_rate()
# Out:
# Improvement Rate:
# LLM ID: 1, Improvement Rate: 49.77%
# LLM ID: 3, Improvement Rate: 49.77%
# LLM ID: 2, Improvement Rate: 50.62%

# %%
def failure_rate_after_annotation():
    Session = sessionmaker(bind=engine)
    session = Session()

    llmresponses_table = metadata.tables['llmresponses']

    query = session.query(
        llmresponses_table.c.llmid,
        (func.count(case(
            (llmresponses_table.c.resultcategory == 'Helpless!', llmresponses_table.c.responseid)
        )) / func.count(func.distinct(llmresponses_table.c.taskid)) * 100).label("failure_rate")
    ).group_by(llmresponses_table.c.llmid)

    print("\nFailure Rate after Annotation:")
    for row in query.all():
        print(f"LLM ID: {row[0]}, Failure Rate after Annotation: {row[1]:.2f}%")

    session.close()

# Call the function
failure_rate_after_annotation()
# Out:
# Failure Rate after Annotation:
# LLM ID: 1, Failure Rate after Annotation: 75.52%
# LLM ID: 2, Failure Rate after Annotation: 85.71%
# LLM ID: 3, Failure Rate after Annotation: 74.15%

# %%
def performance_by_task_level():
    Session = sessionmaker(bind=engine)
    session = Session()

    tasks_table = metadata.tables['tasks']
    llmresponses_table = metadata.tables['llmresponses']
    
    query = session.query(
        llmresponses_table.c.llmid,
        tasks_table.c.level,
        (func.count(case(
            (llmresponses_table.c.resultcategory == 'AS IS', llmresponses_table.c.responseid)
        )) / func.count(func.distinct(llmresponses_table.c.taskid)) * 100).label("performance_by_level")
    ).join(tasks_table, tasks_table.c.taskid == llmresponses_table.c.taskid).group_by(
        llmresponses_table.c.llmid, tasks_table.c.level
    )

    print("\nPerformance by Task Level:")
    for row in query.all():
        print(f"LLM ID: {row[0]}, Task Level: {row[1]}, Performance: {row[2]:.2f}%")

    session.close()

# Call the function
performance_by_task_level()
# Out:
# Performance by Task Level:
# LLM ID: 1, Task Level: 1, Performance: 78.72%
# LLM ID: 1, Task Level: 2, Performance: 83.33%
# LLM ID: 1, Task Level: 3, Performance: 41.67%
# LLM ID: 2, Task Level: 1, Performance: 71.74%
# LLM ID: 2, Task Level: 2, Performance: 87.50%
# LLM ID: 2, Task Level: 3, Performance: 68.18%
# LLM ID: 3, Task Level: 1, Performance: 66.67%
# LLM ID: 3, Task Level: 2, Performance: 73.75%
# LLM ID: 3, Task Level: 3, Performance: 81.82%

# %%
overall_accuracy_per_llm()
accuracy_with_annotation()
improvement_rate()
failure_rate_after_annotation()
performance_by_task_level()
# Out:
# Overall Accuracy per LLM (As Is):
# LLM ID: 1, Accuracy: 67.95%
# LLM ID: 2, Accuracy: 60.47%
# LLM ID: 3, Accuracy: 78.75%
#
# Accuracy with Annotation:
# LLM ID: 1, Accuracy with Annotation: 66.67%
# LLM ID: 2, Accuracy with Annotation: 82.14%
# LLM ID: 3, Accuracy with Annotation: 65.82%
#
# Improvement Rate:
# LLM ID: 1, Improvement Rate: 49.77%
# LLM ID: 3, Improvement Rate: 49.77%
# LLM ID: 2, Improvement Rate: 50.62%
#
# Failure Rate after Annotation:
# LLM ID: 1, Failure Rate after Annotation: 75.52%
# LLM ID: 2, Failure Rate after Annotation: 85.71%
# LLM ID: 3, Failure Rate after Annotation: 74.15%
#
# Performance by Task Level:
# LLM ID: 1, Task Level: 1, Performance: 78.72%
# LLM ID: 1, Task Level: 2, Performance: 83.33%
# LLM ID: 1, Task Level: 3, Performance: 41.67%
# LLM ID: 2, Task Level: 1, Performance: 71.74%
# LLM ID: 2, Task Level: 2, Performance: 87.50%
# LLM ID: 2, Task Level: 3, Performance: 68.18%
# LLM ID: 3, Task Level: 1, Performance: 66.67%
# LLM ID: 3, Task Level: 2, Performance: 73.75%
# LLM ID: 3, Task Level: 3, Performance: 81.82%
